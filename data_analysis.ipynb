# %% [markdown]
# # Data Analysis with CSVs
#
# In this lesson, we'll complete a full data analysis with a raw data file. Comma Separated Values files, known as CSVs, are one of the most common file formats for storing tabular data. In this lesson, we'll show you how to load one into memory and work with it using Python.

# %% [markdown]
# # Objectives
#
# Perform a complete data analysis by...
#
# - Creating a Python data structure from a .csv file
# - Exploring and cleaning the data
# - Conducting descriptive analysis
# - Visualizing the results

# %% [markdown]
# # Loading a CSV
#
# The before you can work with a CSV file, you need to load it into memory.

# %% [markdown]
# ## Get the File Path
#
# Make sure you have the path to your data file. For this example, it is in the root folder of this repository.

# %%
# This will only work on Mac, Linux, or a separate bash terminal in Windows

# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
#  Volume in drive C has no label.
#  Volume Serial Number is AC31-905A
#
#  Directory of C:\Users\david\Documents\GitHub\ds-data_analysis_csv
#
# 04/22/2021  04:58 PM    <DIR>          .
# 04/22/2021  04:58 PM    <DIR>          ..
# 04/22/2021  04:13 PM             1,941 .gitignore
# 04/22/2021  04:28 PM    <DIR>          .ipynb_checkpoints
# 04/22/2021  04:58 PM           981,991 data_analysis.ipynb
# 04/22/2021  04:44 PM         2,160,600 Kings_County_Real_Estate_Sales.csv
# 04/22/2021  04:13 PM            35,823 LICENSE
# 04/22/2021  04:13 PM               183 README.md
#                5 File(s)      3,180,538 bytes
#                3 Dir(s)  98,490,810,368 bytes free

# %% [markdown]
# We use `.` to indicate the root folder of the repository when working within this notebook.

# %%
csv_file_path = "./Kings_County_Real_Estate_Sales.csv"

# %% [markdown]
# ## Inspecting CSV files
#
# In a CSV file, each line represents one row of tabular data, and each value in that row is separated by a comma. Often, the first row contains the column names separated by commas, also known as field names.

# %%
# This will only work on Mac, Linux, or a separate bash terminal in Windows

# !head -n 2 ./Kings_County_Real_Estate_Sales.csv
# Out:
# Couldn't find program: 'bash'

# %% [markdown]
# ## Using the `csv` library
#
# The [`csv` library](https://docs.python.org/3/library/csv.html) lets us process data from and to CSV files. We will use it to read each row in the `.csv` file and store its information in a more usable format.
#
# The [`csv.DictReader`](https://docs.python.org/3/library/csv.html#csv.DictReader) object is a file reader, reading each row and then mapping it to an [OrderedDict](https://docs.python.org/3/library/collections.html#collections.OrderedDict). It uses field names from the first row unless you specify otherwise. Since we know that the first row is the column headers, we can safely omit the `fieldnames` parameter knowing that `csv.DictReader()` will use the first row as the keys within each row.

# %%
import csv

sales = []

with open(csv_file_path) as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        sales.append(row)

# %%
sales
# Out:
# [{'ExciseTaxNbr': '2687551',
#   'Major': '138860',
#   'Minor': '110',
#   'DocumentDate': '08/21/2014',
#   'SalePrice': '245000',
#   'RecordingNbr': '20140828001436',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'WENKLE NOEL SMITH -TRUSTEE                        ',
#   'BuyerName': 'ALEXANDER APRIL                                   ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '3080093',
#   'Major': '82204',
#   'Minor': '9037',
#   'DocumentDate': '10/27/2020',
#   'SalePrice': '0',
#   'RecordingNbr': '20201102000765',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'BALA RAJNI                                        ',
#   'BuyerName': 'SINGH JOGA+BALA RAJNI                             ',
#   'PropertyType': '11',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '18 51'},
#  {'ExciseTaxNbr': '1235111',
#   'Major': '664885',
#   'Minor': '40',
#   'DocumentDate': '07/09/1991',
#   'SalePrice': '0',
#   'RecordingNbr': '199203161090  ',
#   'Volume': '071',
#   'Page': '001',
#   'PlatNbr': '664885',
#   'PlatType': 'C',
#   'PlatLot': 'B102          ',
#   'PlatBlock': '       ',
#   'SellerName': 'HERRMAN JEFFREY A+PAULINE A                       ',
#   'BuyerName': 'HERRMAN PAULINE A TTEE                            ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '3',
#   'SaleWarning': '11'},
#  {'ExciseTaxNbr': '2704079',
#   'Major': '423943',
#   'Minor': '50',
#   'DocumentDate': '10/11/2014',
#   'SalePrice': '0',
#   'RecordingNbr': '20141205000558',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEPHENS ANTHONY P                                ',
#   'BuyerName': 'STEPHENS ANTHONY P                                ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '18 31 51'},
#  {'ExciseTaxNbr': '2584094',
#   'Major': '403700',
#   'Minor': '715',
#   'DocumentDate': '01/04/2013',
#   'SalePrice': '0',
#   'RecordingNbr': '20130110000910',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'PASTORS EDWIN                                     ',
#   'BuyerName': 'PASTORS KHRISTINA                                 ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '11',
#   'PropertyClass': '8',
#   'SaleWarning': '18 31 38'},
#  {'ExciseTaxNbr': '3027422',
#   'Major': '213043',
#   'Minor': '120',
#   'DocumentDate': '12/20/2019',
#   'SalePrice': '560000',
#   'RecordingNbr': '20191226000848',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'DOYLE REGAN M+STERLING C                          ',
#   'BuyerName': 'SHAW HEATHER C                                    ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '1056831',
#   'Major': '951120',
#   'Minor': '900',
#   'DocumentDate': '04/20/1989',
#   'SalePrice': '85000',
#   'RecordingNbr': '198904260448  ',
#   'Volume': '117',
#   'Page': '053',
#   'PlatNbr': '951120',
#   'PlatType': 'P',
#   'PlatLot': '90            ',
#   'PlatBlock': '       ',
#   'SellerName': 'STRATHY FLORENCE G                                ',
#   'BuyerName': 'PORTER DONALD D+EVELYN V                          ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '9',
#   'SaleWarning': '49'},
#  {'ExciseTaxNbr': '1971467',
#   'Major': '605475',
#   'Minor': '10',
#   'DocumentDate': '07/07/2003',
#   'SalePrice': '0',
#   'RecordingNbr': '20030708003207',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'FUETTERER MARY ANNA C+NIPPER BILL B               ',
#   'BuyerName': 'NIPPER BILL BRUCE                                 ',
#   'PropertyType': '6',
#   'PrincipalUse': '2',
#   'SaleInstrument': '22',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '8',
#   'PropertyClass': '3',
#   'SaleWarning': '12 31 51'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '122209',
#   'Minor': '9002',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '122209',
#   'Minor': '9001',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '12307',
#   'Minor': '9020',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '12307',
#   'Minor': '9005',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '22209',
#   'Minor': '9001',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '22209',
#   'Minor': '9003',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '342309',
#   'Minor': '9012',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '342309',
#   'Minor': '9011',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '342309',
#   'Minor': '9015',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '342309',
#   'Minor': '9010',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '62210',
#   'Minor': '9010',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '182210',
#   'Minor': '9001',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '282309',
#   'Minor': '9011',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '332309',
#   'Minor': '9004',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '1813750',
#   'Major': '22209',
#   'Minor': '9007',
#   'DocumentDate': '04/25/2001',
#   'SalePrice': '5755000',
#   'RecordingNbr': '20010426001305',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MANKE LUMBER CO INC                               ',
#   'BuyerName': 'WASHINGTON STATE OF                               ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '11 16 45'},
#  {'ExciseTaxNbr': '714942',
#   'Major': '284150',
#   'Minor': '10',
#   'DocumentDate': '04/06/1983',
#   'SalePrice': '91500',
#   'RecordingNbr': '198304110267  ',
#   'Volume': '100',
#   'Page': '057',
#   'PlatNbr': '284150',
#   'PlatType': 'P',
#   'PlatLot': '01            ',
#   'PlatBlock': '       ',
#   'SellerName': 'GOODWIN TERENCE                                   ',
#   'BuyerName': 'MITCHELL PHILLIP J+ROSARIO QUE                    ',
#   'PropertyType': '2',
#   'PrincipalUse': '6',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': ' ',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '1729614',
#   'Major': '172204',
#   'Minor': '9157',
#   'DocumentDate': '12/21/1999',
#   'SalePrice': '0',
#   'RecordingNbr': '19991229001498',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GRIFFIN WILLIAM R                                 ',
#   'BuyerName': 'DESIMONE TERESA J                                 ',
#   'PropertyType': '3',
#   'PrincipalUse': '11',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '10',
#   'PropertyClass': '8',
#   'SaleWarning': '31 45'},
#  {'ExciseTaxNbr': '1729614',
#   'Major': '172204',
#   'Minor': '9005',
#   'DocumentDate': '12/21/1999',
#   'SalePrice': '0',
#   'RecordingNbr': '19991229001498',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GRIFFIN WILLIAM R                                 ',
#   'BuyerName': 'DESIMONE TERESA J                                 ',
#   'PropertyType': '3',
#   'PrincipalUse': '11',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '10',
#   'PropertyClass': '8',
#   'SaleWarning': '31 45'},
#  {'ExciseTaxNbr': '2254430',
#   'Major': '192304',
#   'Minor': '9020',
#   'DocumentDate': '12/05/2006',
#   'SalePrice': '0',
#   'RecordingNbr': '20061207002200',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'WESBILD BP INC                                    ',
#   'BuyerName': 'BURIEN CITY OF                                    ',
#   'PropertyType': '3',
#   'PrincipalUse': '11',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '2',
#   'SaleWarning': '18 45'},
#  {'ExciseTaxNbr': '685277',
#   'Major': '885730',
#   'Minor': '120',
#   'DocumentDate': '08/11/1982',
#   'SalePrice': '0',
#   'RecordingNbr': '198208170380  ',
#   'Volume': '086',
#   'Page': '075',
#   'PlatNbr': '885730',
#   'PlatType': 'P',
#   'PlatLot': '12            ',
#   'PlatBlock': '       ',
#   'SellerName': 'CASSERD FREDA                                     ',
#   'BuyerName': 'HOWE HELENE C                                     ',
#   'PropertyType': '3',
#   'PrincipalUse': '2',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': ' ',
#   'SaleReason': '1',
#   'PropertyClass': '3',
#   'SaleWarning': '11'},
#  {'ExciseTaxNbr': '961971',
#   'Major': '165730',
#   'Minor': '360',
#   'DocumentDate': '08/25/1987',
#   'SalePrice': '37500',
#   'RecordingNbr': '198709010133  ',
#   'Volume': '136',
#   'Page': '080',
#   'PlatNbr': '165730',
#   'PlatType': 'P',
#   'PlatLot': '36            ',
#   'PlatBlock': '       ',
#   'SellerName': 'PLATT DALE+CAROL ANN                              ',
#   'BuyerName': 'HART RODERICK G SR+CAROLYN                        ',
#   'PropertyType': '1',
#   'PrincipalUse': '0',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2857854',
#   'Major': '198920',
#   'Minor': '1430',
#   'DocumentDate': '03/28/2017',
#   'SalePrice': '0',
#   'RecordingNbr': '20170410000541',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'AD APARTMENTS LLC                                 ',
#   'BuyerName': 'SEATTLE CITY OF                                   ',
#   'PropertyType': '3',
#   'PrincipalUse': '7',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '2',
#   'SaleWarning': '20 31'},
#  {'ExciseTaxNbr': '2546588',
#   'Major': '858140',
#   'Minor': '376',
#   'DocumentDate': '05/22/2012',
#   'SalePrice': '0',
#   'RecordingNbr': '20120601000823',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MECKLE RICKIE A                                   ',
#   'BuyerName': 'MECKLE SHIRLEY R                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '11',
#   'PropertyClass': '7',
#   'SaleWarning': '18 31 38'},
#  {'ExciseTaxNbr': '1157170',
#   'Major': '674470',
#   'Minor': '1265',
#   'DocumentDate': '06/08/1990',
#   'SalePrice': '0',
#   'RecordingNbr': '199009241509  ',
#   'Volume': '011',
#   'Page': '099',
#   'PlatNbr': '674470',
#   'PlatType': 'P',
#   'PlatLot': 'R PT          ',
#   'PlatBlock': '62     ',
#   'SellerName': 'RUUD LANE D $ER                                   ',
#   'BuyerName': 'RUUD LANE D                                       ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '18',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '8',
#   'SaleWarning': '20'},
#  {'ExciseTaxNbr': '1709671',
#   'Major': '921440',
#   'Minor': '240',
#   'DocumentDate': '09/08/1999',
#   'SalePrice': '292000',
#   'RecordingNbr': '19990910001148',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MARTIN THOMAS ROBERT+ANN                          ',
#   'BuyerName': 'CLARK DANIEL J+NULF JENNIFER G                    ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2420985',
#   'Major': '234130',
#   'Minor': '265',
#   'DocumentDate': '12/04/2009',
#   'SalePrice': '287000',
#   'RecordingNbr': '20091209001633',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'NGO THANH+EM                                      ',
#   'BuyerName': 'LE TUAN D+TINA T HO                               ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '120',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '160',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '260',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '180',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '140',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '240',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '50',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '130',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '10',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '210',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '60',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2043998',
#   'Major': '785996',
#   'Minor': '250',
#   'DocumentDate': '05/27/2004',
#   'SalePrice': '5518000',
#   'RecordingNbr': '20040602001705',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'STEVENWOOD LLC                                    ',
#   'BuyerName': 'SONOMA PLACE LLC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45'},
#  {'ExciseTaxNbr': '2671216',
#   'Major': '98400',
#   'Minor': '380',
#   'DocumentDate': '04/02/2014',
#   'SalePrice': '0',
#   'RecordingNbr': '20140602000186',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'DWORSHAK LYNDEE MARIE                             ',
#   'BuyerName': 'DWORSHAK MICHAEL J                                ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '11',
#   'PropertyClass': '8',
#   'SaleWarning': '18 31 38'},
#  {'ExciseTaxNbr': '2201052',
#   'Major': '889980',
#   'Minor': '280',
#   'DocumentDate': '03/03/2006',
#   'SalePrice': '0',
#   'RecordingNbr': '20060420001615',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MOORE JEFFERY A                                   ',
#   'BuyerName': 'HAMPTON JAMES W+VICTORIA A                        ',
#   'PropertyType': '3',
#   'PrincipalUse': '2',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '14',
#   'PropertyClass': '3',
#   'SaleWarning': '18 31 51 52'},
#  {'ExciseTaxNbr': '2548641',
#   'Major': '330395',
#   'Minor': '1610',
#   'DocumentDate': '06/07/2012',
#   'SalePrice': '335000',
#   'RecordingNbr': '20120615000867',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'THORSON CONNIE+TODD                               ',
#   'BuyerName': 'YATTEAU PAUL A+TAMARA J                           ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '1598443',
#   'Major': '675260',
#   'Minor': '940',
#   'DocumentDate': '03/06/1998',
#   'SalePrice': '209950',
#   'RecordingNbr': '199803122092  ',
#   'Volume': '165',
#   'Page': '041',
#   'PlatNbr': '675260',
#   'PlatType': 'P',
#   'PlatLot': '94            ',
#   'PlatBlock': '       ',
#   'SellerName': 'HART JOHN W II+ANDREA T                           ',
#   'BuyerName': 'HANSON KEVIN P+JENNA M                            ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2339550',
#   'Major': '795508',
#   'Minor': '170',
#   'DocumentDate': '03/28/2008',
#   'SalePrice': '0',
#   'RecordingNbr': '20080331002272',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'SCHWEIGER MICHAEL M                               ',
#   'BuyerName': 'SCHWEIGER MICHAEL W                               ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '18 31 51'},
#  {'ExciseTaxNbr': '1766926',
#   'Major': '269549',
#   'Minor': '190',
#   'DocumentDate': '07/23/2000',
#   'SalePrice': '154950',
#   'RecordingNbr': '20000727000693',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'HASTINGS MARGARET JOANN                           ',
#   'BuyerName': 'CLINTON MICHELLE A+JEFF S                         ',
#   'PropertyType': '3',
#   'PrincipalUse': '2',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '3',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2743355',
#   'Major': '638580',
#   'Minor': '110',
#   'DocumentDate': '07/14/2015',
#   'SalePrice': '190000',
#   'RecordingNbr': '20150715002686',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GINGRICH AUDREY B                                 ',
#   'BuyerName': 'NATION FRED I                                     ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': '15'},
#  {'ExciseTaxNbr': '1684472',
#   'Major': '252206',
#   'Minor': '9011',
#   'DocumentDate': '02/12/1999',
#   'SalePrice': '0',
#   'RecordingNbr': '199905122132  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'SPANNER DEKEN DEREK                               ',
#   'BuyerName': 'SPANNER ROBERTA LYNN                              ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '11',
#   'PropertyClass': '8',
#   'SaleWarning': '31 38'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '50',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '40',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '30',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '110',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '90',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '80',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '170',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '60',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '120',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '130',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '200',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '100',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '160',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '10',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '2040352',
#   'Major': '321165',
#   'Minor': '180',
#   'DocumentDate': '05/10/2004',
#   'SalePrice': '2100000',
#   'RecordingNbr': '20040520002374',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'W E RUTH REAL ESTATE INC                          ',
#   'BuyerName': 'MJF HOLDINGS INC                                  ',
#   'PropertyType': '1',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': '45 56'},
#  {'ExciseTaxNbr': '1217902',
#   'Major': '142308',
#   'Minor': '9083',
#   'DocumentDate': '10/11/1991',
#   'SalePrice': '0',
#   'RecordingNbr': '199111192110  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'HARGRAVES PAUL+GERALDINE O                        ',
#   'BuyerName': 'HARGARVES PAUL+GERALDINE TTEES                    ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '11'},
#  {'ExciseTaxNbr': '1217902',
#   'Major': '142308',
#   'Minor': '9003',
#   'DocumentDate': '10/11/1991',
#   'SalePrice': '0',
#   'RecordingNbr': '199111192110  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
# ...
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '13',
#   'PropertyClass': '8',
#   'SaleWarning': '18 31 51'},
#  {'ExciseTaxNbr': '2144911',
#   'Major': '611440',
#   'Minor': '28',
#   'DocumentDate': '07/29/2005',
#   'SalePrice': '396000',
#   'RecordingNbr': '20050805001945',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'MATTHEWS RANDOLPH S                               ',
#   'BuyerName': 'CAVUOTO SCOTT A+EMELIA M                          ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '5',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '3051214',
#   'Major': '262408',
#   'Minor': '9210',
#   'DocumentDate': '06/02/2020',
#   'SalePrice': '769000',
#   'RecordingNbr': '20200611001758',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'L&L DEVELOPMENT LLC                               ',
#   'BuyerName': 'SANDQUIST JEFFREY DEAN+LAURI ANN                  ',
#   'PropertyType': '91',
#   'PrincipalUse': '6',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '7',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '112107',
#   'Minor': '9001',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '112107',
#   'Minor': '9009',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '112107',
#   'Minor': '9016',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '112107',
#   'Minor': '9014',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '52007',
#   'Minor': '9012',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '352206',
#   'Minor': '9001',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '352206',
#   'Minor': '9018',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '312307',
#   'Minor': '9002',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '12106',
#   'Minor': '9002',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '1483776',
#   'Major': '22106',
#   'Minor': '9001',
#   'DocumentDate': '04/04/1996',
#   'SalePrice': '0',
#   'RecordingNbr': '199605080095  ',
#   'Volume': '000',
#   'Page': '000',
#   'PlatNbr': '000000',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'GLACIER PARK COMPANY                              ',
#   'BuyerName': 'PLUM CREEK TIMBER COMPANY L.P                     ',
#   'PropertyType': '1',
#   'PrincipalUse': '9',
#   'SaleInstrument': '26',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '0',
#   'SaleWarning': '20 32 45'},
#  {'ExciseTaxNbr': '2589396',
#   'Major': '600300',
#   'Minor': '1585',
#   'DocumentDate': '02/04/2013',
#   'SalePrice': '0',
#   'RecordingNbr': '20130215001300',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'HAYAKAWA JANET SUE+JUNE C H                       ',
#   'BuyerName': 'HAYAKAWA JUNE C+JANET SUE                         ',
#   'PropertyType': '3',
#   'PrincipalUse': '11',
#   'SaleInstrument': '18',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '5',
#   'PropertyClass': '2',
#   'SaleWarning': '22 31 51'},
#  {'ExciseTaxNbr': '1166737',
#   'Major': '865151',
#   'Minor': '520',
#   'DocumentDate': '11/20/1990',
#   'SalePrice': '212500',
#   'RecordingNbr': '199012030575  ',
#   'Volume': '114',
#   'Page': '069',
#   'PlatNbr': '865151',
#   'PlatType': 'P',
#   'PlatLot': '52            ',
#   'PlatBlock': '       ',
#   'SellerName': 'ANDERSON PHILLIP D+MICHELLE K                     ',
#   'BuyerName': 'FINKLE MICHAEL F+                                 ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '3100898',
#   'Major': '660790',
#   'Minor': '500',
#   'DocumentDate': '07/24/2013',
#   'SalePrice': '0',
#   'RecordingNbr': '20210223002513',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'CHON ANTONIA+DWORKIN STEPHEN A                    ',
#   'BuyerName': 'TYNER ALICE L                                     ',
#   'PropertyType': '14',
#   'PrincipalUse': '2',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '16',
#   'PropertyClass': '3',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2832394',
#   'Major': '335540',
#   'Minor': '245',
#   'DocumentDate': '11/02/2016',
#   'SalePrice': '201972',
#   'RecordingNbr': '              ',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'QUALITY LOAN SERVICE CORP OF WA                   ',
#   'BuyerName': 'U S BANK NA                                       ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '18',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '4',
#   'PropertyClass': '8',
#   'SaleWarning': '15 31'},
#  {'ExciseTaxNbr': '2705914',
#   'Major': '192405',
#   'Minor': '9120',
#   'DocumentDate': '10/10/2014',
#   'SalePrice': '0',
#   'RecordingNbr': '20141217000731',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'ANDERSON ELEANOR R -TTEE                          ',
#   'BuyerName': 'BRITT JEFFREY LEE -TTEE & PR                      ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '12 18 31 45 51 52'},
#  {'ExciseTaxNbr': '2705914',
#   'Major': '192405',
#   'Minor': '9062',
#   'DocumentDate': '10/10/2014',
#   'SalePrice': '0',
#   'RecordingNbr': '20141217000731',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'ANDERSON ELEANOR R -TTEE                          ',
#   'BuyerName': 'BRITT JEFFREY LEE -TTEE & PR                      ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '12 18 31 45 51 52'},
#  {'ExciseTaxNbr': '1600323',
#   'Major': '279610',
#   'Minor': '760',
#   'DocumentDate': '03/17/1998',
#   'SalePrice': '0',
#   'RecordingNbr': '199803231985  ',
#   'Volume': '105',
#   'Page': '028',
#   'PlatNbr': '279610',
#   'PlatType': 'P',
#   'PlatLot': '76            ',
#   'PlatBlock': '       ',
#   'SellerName': 'SIMONS LESLIE L                                   ',
#   'BuyerName': 'SIMONS PETER ALAN                                 ',
#   'PropertyType': '0',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '11',
#   'PropertyClass': '0',
#   'SaleWarning': '32 38'},
#  {'ExciseTaxNbr': '3012934',
#   'Major': '615490',
#   'Minor': '10',
#   'DocumentDate': '09/24/2019',
#   'SalePrice': '775000',
#   'RecordingNbr': '20190930002488',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'TALBOT MORGAN P                                   ',
#   'BuyerName': 'FICHTER CAROLINE                                  ',
#   'PropertyType': '11',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '3097127',
#   'Major': '142604',
#   'Minor': '9084',
#   'DocumentDate': '01/29/2021',
#   'SalePrice': '0',
#   'RecordingNbr': '20210201000182',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'POSTETTER DAVID EDWARD III+LIZABETH JEAN          ',
#   'BuyerName': 'POSTETTER DAVID EDWARD III+LIZABETH JEAN+ET AL    ',
#   'PropertyType': '11',
#   'PrincipalUse': '6',
#   'SaleInstrument': '15',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '18',
#   'PropertyClass': '8',
#   'SaleWarning': '51'},
#  {'ExciseTaxNbr': '1261538',
#   'Major': '942950',
#   'Minor': '260',
#   'DocumentDate': '08/01/1992',
#   'SalePrice': '175000',
#   'RecordingNbr': '199208060955  ',
#   'Volume': '038',
#   'Page': '026',
#   'PlatNbr': '942950',
#   'PlatType': 'P',
#   'PlatLot': 'TR 54         ',
#   'PlatBlock': '       ',
#   'SellerName': 'RYAN GERALDINE A                                  ',
#   'BuyerName': 'CARR ALAN RYAN+KAREN A                            ',
#   'PropertyType': '3',
#   'PrincipalUse': '0',
#   'SaleInstrument': '2',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  {'ExciseTaxNbr': '2057845',
#   'Major': '142305',
#   'Minor': '9056',
#   'DocumentDate': '07/26/2004',
#   'SalePrice': '247000',
#   'RecordingNbr': '20040727002476',
#   'Volume': '   ',
#   'Page': '   ',
#   'PlatNbr': '      ',
#   'PlatType': ' ',
#   'PlatLot': '              ',
#   'PlatBlock': '       ',
#   'SellerName': 'HINDES LAURIE A                                   ',
#   'BuyerName': 'SMITH MELODY L                                    ',
#   'PropertyType': '3',
#   'PrincipalUse': '6',
#   'SaleInstrument': '3',
#   'AFForestLand': 'N',
#   'AFCurrentUseLand': 'N',
#   'AFNonProfitUse': 'N',
#   'AFHistoricProperty': 'N',
#   'SaleReason': '1',
#   'PropertyClass': '8',
#   'SaleWarning': ' '},
#  ...]

# %% [markdown]
# The contents of `sales[0]` is exactly the same as it was when we viewed the first two records of the `raw_data/EXTR_RPSale.csv` file from the command line.

# %%
sales[0]

# %% [markdown]
# ## Clean the Sale Prices
#
# First, let's convert the sale prices from strings to numbers, so we can do arithmetic with them. For example, this will let us find the average price.

# %%
for sale in sales:
    # Save the document date to a variable
    string_price = sale["SalePrice"]
    
    # Cast the sale price to int and add to each dictionary element of sales
    sale["sale_price"] = int(string_price)

# %%
sales[0]

# %% [markdown]
# ## Clean the Dates
#
# Next we'll clean the dates so that we can easily get the month and year of each sale.

# %% [markdown]
# ### Using Python built-in methods
#
# **Discussion**: How could you process the `sales` list to add numeric values for month and year to each entry?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#
#     for sale in sales:
#         # Save the document date to a variable
#         string_date = sale["DocumentDate"]
#
#         # Extract the sale year and month from the string, and cast to int
#         sale_year = int(string_date[6:10])
#         sale_month = int(string_date[0:2])
#
#         # Add the sale year and month to each dictionary element of sales
#         sale["sale_year"] = sale_year
#         sale["sale_month"] = sale_month
# </details>

# %%
## Your work here

# %%
sales[0]

# %% [markdown]
# # Data Analysis
#
# Now that you have a cleaned list with the property sales data, we can finally start to perform some data analysis.

# %% [markdown]
# ## Question 1: What is the range of years for which we have sales data?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#
#     sale_years = [sale['sale_year'] for sale in sales]
#     print(min(sale_years))
#     print(max(sale_years))
# </details>

# %%
## Your work here

# %% [markdown]
# ## Question 2: How many properties sold in 2020?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#
#     sale_years = [sale['sale_year'] for sale in sales]
#     sale_years_2020 = [year for year in sale_years if year == 2020]
#     len(sale_years_2020)
# </details>

# %%
## Your work here

# %% [markdown]
# ## Question 3: What was the mean sale price in 2020?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#
#     sale_prices_2020 = [sale['sale_price'] for sale in sales if sale['sale_year'] == 2020]
#     sum(sale_prices_2020)/len(sale_prices_2020)
# </details>

# %%
## Your work here

# %% [markdown]
# ## Level Up: How many properties sold in each year?

# %% [markdown]
# For all dictionaries in `sales`, we want to count how many property sales occured in each year. Since the value in `sale_year` is an integer, we can use Python's built-in [`sorted`](https://docs.python.org/3/library/functions.html#sorted) function to transform the `Counter` object into a `list` of `tuples` - `(year, count)` which are sorted in ascending order by year.

# %%
from collections import Counter

sale_year_count = Counter([sale['sale_year'] for sale in sales])

# %%
sale_year_count

# %%
sale_year_count = sorted(sale_year_count.items())
sale_year_count

# %% [markdown]
# ### Chart the Data

# %% [markdown]
# This `list` of `tuples` is helpful, but it takes a lot of effort to read it and make sense of the trends - let's visualize the results to make this easier. We'll do this with `matplotlib`, which you'll learn about in a future lesson.

# %%
from matplotlib import pyplot as plt

# %%
# create a figure and one plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

# place data in a bar chart 
# where the x-axis is each year and 
# the y-axis is the number of sales per year
ax.bar(x=[sale[0] for sale in sale_year_count],
       height=[sale[1] for sale in sale_year_count])

# set axis labels
ax.set_xlabel("Year")
ax.set_ylabel("Number of property sales")

# give the bar chart a title
ax.set_title("Property sales in King County, WA (1900 to 2021)")

# display bar chart clearly
fig.tight_layout()

# %% [markdown]
# By the looks of our number of property sales over time bar plot, it looks like property sales in King County, WA started taking off in the 1980s. They continued climbing into the early 2000s. Despite the recession reducing the number of home sales in the late 2000s, it looks like they are continuing to climb.

# %% [markdown]
# ### Save the Chart

# %% [markdown]
# Let's create a new `visuals` folder that will store all of our visuals, and save this chart there.

# %%
# !mkdir visuals

# %%
# save a copy of the figure as a PNG
fig.savefig("visuals/raw_sales_count_by_year.png",
            dpi=150)

# %% [markdown]
# ### Level Up: Using `datetime`

# %% [markdown]
# Python has a [`datetime`](https://docs.python.org/3.7/library/datetime.html) package that is the standard tool for handling dates and times. `datetime` objects make it easy to do fun things like subtract dates to calculate how far apart they are.

# %%
from datetime import datetime

# %%
for sale in sales:
    # Transform DocumentDate from string to datetime
    sale["clean_date"] = datetime.strptime(sale["DocumentDate"], 
                                           "%m/%d/%Y")
    
    # Add the sale year and month to each dictionary element of sales
    sale["sale_year"] = sale["clean_date"].year
    sale["sale_month"] = sale["clean_date"].month

# %% [markdown]
# Let's inspect our work

# %%
sales[0]
